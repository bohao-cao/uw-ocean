# %%
#url = "https://docs.google.com/spreadsheets/d/1eZj7EOdGe16P5QWHSIIHhkclNAog13e7xF6fPMoXfEY/edit#gid=1897262175"
name = "main"

import pandas as pd
import urllib.parse

sheet_id = "1eZj7EOdGe16P5QWHSIIHhkclNAog13e7xF6fPMoXfEY"
sheet_name = "Buy_Insta_Accounts"
#sheet_name_encoded = urllib.parse.quote(sheet_name)
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
fn = "Anthony MainSheet [current projects] - Buy_Insta_Accounts.tsv"
Buy_Insta_Accounts_df = pd.read_csv(fn, sep="\t")

# %% [markdown]
# ## Load data

# %%
import os 
import pandas as pd

files = os.listdir("data")

df_women_event = pd.read_csv(os.path.join("data", files[0]), sep="\t")
df_buy_insta_accounts_add_on = pd.read_csv(os.path.join("data", files[1]), sep="\t")
df_buy_biz = pd.read_csv(os.path.join("data", files[2]), sep="\t")
df_buy_insta_accounts = pd.read_csv(os.path.join("data", files[3]), sep="\t")
df_women_event_mined = pd.read_csv(os.path.join("data", files[4]), sep="\t")

# %% [markdown]
# ## EDA

# %%
df_buy_biz.media_count.describe()
# Out:
# count     143.000000
# mean      405.426573
# std       583.785926
# min         0.000000
# 25%        54.000000
# 50%       166.000000
# 75%       481.500000
# max      3813.000000
# Name: media_count, dtype: float64

# %%
df_women_event_mined.columns
# Out:
# Index(['username', 'userid', 'scraped_from', 'media_count', 'full_name',
#        'following_count', 'follower_count', 'first_name', 'external_url',
#        'email', 'contact_phone_number', 'cityName', 'category', 'biography',
#        'address_street', 'Big 5'],
#       dtype='object')

# %%
df_buy_insta_accounts.columns
# Out:
# Index(['username', 'Openness', 'Conscientiousness', 'Extroversion',
#        'Agreeableness', 'Neuroticism', 'Type', 'media_count', 'full_name',
#        'following_count', 'follower_count', 'first_name', 'external_url',
#        'engagement_percent', 'email', 'contact_phone_number', 'cityName',
#        'category', 'biography', 'address_street', 'AvgLikes', 'AvgComments'],
#       dtype='object')

# %%
df_buy_biz[df_buy_biz['Openness'].notna()]
# Out:
#                   username Openness Conscientiousness Extroversion  \
# 0               goodeatzco      Low              High         High
# 2               a1republic     High              High         High
# 3           keychainsocial     High              High         High
# 4        thegiftshoppe.nft    Vague               Low          Low
# 5       officialclubsocial      Low              High         High
# ..                     ...      ...               ...          ...
# 138           irose.social     High              High         High
# 139               nattcity     High               Low         High
# 140             jondennill     High              High         High
# 141            igmodels_co      Low              High        Vague
# 142  skystrategicmarketing     High              High         High
#
#     Agreeableness Neuroticism      Type  media_count                full_name  \
# 0           Vague       Vague      Blog         1693       #GoodEatzCo | Andy
# 2            High         Low  Business           30            A1 REPUBLIC ™
# 3            High         Low  Business          214    Keychain Social, Inc.
# 4           Vague       Vague  Business            9          the gift shoppe
# 5           Vague       Vague  Business            6              Club Social
# ..            ...         ...       ...          ...                      ...
# 138           Low         Low  Business          338                    IROSE
# 139           Low         Low  Personal         1129                 nathalie
# 140          High         Low  Personal          124         Jonathan Dennill
# 141         Vague       Vague      Blog          458    IG Models Worldwide ®
# 142          High         Low  Business          427  Sky Strategic Marketing
#
#      following_count  ...  engagement_percent  \
# 0                145  ...                0.14
# 2                613  ...                0.53
# 3                  0  ...                 NaN
# 4                  5  ...                0.57
# 5                  2  ...                 NaN
# ..               ...  ...                 ...
# 138              422  ...                0.30
# 139              686  ...                0.06
# 140              733  ...                0.49
# 141              158  ...                0.01
# 142             2133  ...                0.18
#
#                                email contact_phone_number  \
# 0               goodeatzco@gmail.com                  NaN
# 2               a1republic@yahoo.com         1.949934e+10
# 3            info@keychainsocial.com                  NaN
# 4        hello@fromthegiftshoppe.com                  NaN
# 5           clubsocialmgmt@gmail.com                  NaN
# ..                               ...                  ...
# 138           sharon@irosesocial.com                  NaN
# 139  nathalia@nfluenceconsulting.com                  NaN
# 140            jon.dennill@gmail.com                  NaN
# 141            igmodels.co@gmail.com                  NaN
# 142  tanya@skystrategicmarketing.com         1.813337e+10
#
#                       cityName             category  \
# 0      Los Angeles, California              Blogger
# 2    Newport Beach, California  Social Media Agency
# 3      Los Angeles, California                  NaN
# 4                          NaN                  NaN
# 5      Los Angeles, California  Social Media Agency
# ..                         ...                  ...
# 138    Los Angeles, California      Product/service
# 139                        NaN                Actor
# 140                        NaN                  NaN
# 141    Los Angeles, California  Social Media Agency
# 142             Tampa, Florida                  NaN
#
#                                              biography  \
# 0    🍴Professional Food Consumer🤘🏻😛 Tiktok 🎥: @good...
# 2    The #1 organic IG growth service for influence...
# 3    Digital Social Media Agency • Unlock Your Pote...
# 4    by @jeremyfall + @aa.nft an nft agency ✉️ hell...
# 5          #1 Influencer Management Agency CLUB LIFE 🌎
# ..                                                 ...
# 138  Content | Photography | Events | Marketing 📸 b...
# 139  𝘐𝘯𝘧𝘭𝘶𝘦𝘯𝘤𝘦 𝘱𝘰𝘴𝘪𝘵𝘪𝘷𝘦 𝘤𝘩𝘢𝘯𝘨𝘦 ♡ + full time boy ma...
# 140  Digital Producer & Creative Media Manager 📱 So...
# 141  Follow The Official #IGModels Account ▪︎Exclus...
# 142  Full service advertising agency in Tampa that ...
#
#               address_street   MostRecentPostDate  AvgLikes AvgComments
# 0                        NaN  2022-01-04 20:52:16   5407.11       41.17
# 2                        NaN  2021-03-30 19:31:57   5859.94       73.22
# 3                        NaN   2020-01-22 9:56:45  19273.17         NaN
# 4                        NaN  2021-02-16 23:17:40   1451.00       55.89
# 5                        NaN  2020-10-19 10:31:05     69.33         NaN
# ..                       ...                  ...       ...         ...
# 138                      NaN  2022-01-03 22:26:32     24.33        7.67
# 139                      NaN  2022-01-03 22:13:06    535.39       51.17
# 140                      NaN  2021-12-26 18:30:05     47.17        2.94
# 141                      NaN  2021-09-26 13:33:30    324.56        1.72
# 142  1906 N Armenia Ave #315  2021-12-25 16:00:06     16.89        1.33
#
# [129 rows x 23 columns]

# %%
len(df_buy_insta_accounts_add_on)
# Out:
# 2734

# %%
df_buy_insta_accounts_add_on
# Out:
#                   username Openness Conscientiousness Extroversion  \
# 0        patrickbreenmusic      Low              High          Low
# 1     love.lindsey.wheeler     High              High         High
# 2             authorkwells     High               Low         High
# 3        aleksatodorovicev     High              High         High
# 4         grigoruadisveley     High              High         High
# ...                    ...      ...               ...          ...
# 2729        danielarendonn      NaN               NaN          NaN
# 2730         the_fifthguys      NaN               NaN          NaN
# 2731              mskialee      NaN               NaN          NaN
# 2732        beckie_farrant      NaN               NaN          NaN
# 2733          mikelonghelt      NaN               NaN          NaN
#
#      Agreeableness Neuroticism      Type  media_count  \
# 0             High         Low  Personal          504
# 1             High         Low  Personal         2381
# 2             High         Low  Personal          129
# 3              Low         Low  Personal          897
# 4              Low         Low  Personal        10742
# ...            ...         ...       ...          ...
# 2729           NaN         NaN       NaN          408
# 2730           NaN         NaN       NaN          167
# 2731           NaN         NaN       NaN          236
# 2732           NaN         NaN       NaN         2109
# 2733           NaN         NaN       NaN          987
#
#                           full_name  following_count  ...  \
# 0                     Patrick Breen              893  ...
# 1                   LINDSEY WHEELER             1332  ...
# 2     Author Kamisha Wells RDKS CEO              314  ...
# 3                 Todorović Aleksa              876  ...
# 4       Anzhelika Grigoryadis Veley              980  ...
# ...                             ...              ...  ...
# 2729                 Daniela Rendon               36  ...
# 2730                  The FifthGuys              420  ...
# 2731          Ms. Lee/ Royalty حقية              102  ...
# 2732                 Beckie Farrant             1339  ...
# 2733                   mikelonghelt              539  ...
#
#                                            external_url engagement_percent  \
# 0                                                   NaN              2.793
# 1                          https://www.lovelindsey.com/              1.063
# 2              https://www.amazon.com/shop/authorkwells              1.804
# 3                   https://linktr.ee/aleksatodorovicev              0.703
# 4                   https://paysend.com/referral/01g6gi              0.470
# ...                                                 ...                ...
# 2729                   https://linktr.ee/danielarendonn              0.674
# 2730                      https://discord.gg/CpdVpPaZXu              0.777
# 2731                         https://linktr.ee/MSKIALEE              0.045
# 2732  https://www.greatstuff.dupont.com/great-pantry...              0.498
# 2733                             https://ffm.to/mmlqzdw              0.274
#
#                                  email  contact_phone_number  \
# 0        patrick@patrickbreenmusic.com                   NaN
# 1            lindseyslularoe@gmail.com          +17576206307
# 2               kamishawells@yahoo.com          +15627350110
# 3            todorovicaskela@gmail.com                   NaN
# 4     anzhelika-grigorjadis@rambler.ru                   NaN
# ...                                ...                   ...
# 2729         daniela@danielarendon.com          +17868997656
# 2730    thefifthguysofficial@gmail.com                   NaN
# 2731              klee@keybridgeus.com          +17706424307
# 2732     infarrantlycreative@gmail.com                   NaN
# 2733               mlonghelt@gmail.com                   NaN
#
#                      cityName         category  \
# 0                         NaN         Musician
# 1                         NaN     Entrepreneur
# 2     Los Angeles, California           Author
# 3                         NaN  Digital creator
# 4                         NaN    Public figure
# ...                       ...              ...
# 2729                      NaN     Entrepreneur
# 2730                      NaN    Musician/band
# 2731                      NaN    Public figure
# 2732                      NaN         Interest
# 2733                      NaN              NaN
#
#                                               biography address_street  \
# 0             📍Los Angeles ✨🎵 Morning Light - OUT NOW 👇            NaN
# 1     ☕️ Caffeine, cute clothes & plenty of humor 🤣 ...            NaN
# 2     📚Available on @amazon | ARF Grouphome| Entrepr...            NaN
# 3     PR & Digital Marketing Specialist Menswear | T...            NaN
# 4     🎡🗽✈️🏝📱🛸Official account ✈️#london 🅰️PR manager...            NaN
# ...                                                 ...            ...
# 2729  👱🏻‍♀️| Join My World  🌎| Business in 18+ count...            NaN
# 2730  🇮🇹 @justpave_5g & @steppan_5g  CEO / A&R / Pla...            NaN
# 2731  🌸🧘🏾‍♂️𝐒𝐔𝐂𝐂𝐄𝐒𝐒 𝐈𝐍 𝐀𝐋𝐋 𝐀𝐑𝐄𝐀𝐒 𝐎𝐅 𝐋𝐈𝐅𝐄 🌸𝐘𝐎𝐔𝐑 Part ...            NaN
# 2732  DIY girl 🔨sarcastic red head ❤️ entrepreneur 💪...            NaN
# 2733  Music Producer/DJ/Vocalist Brand new track “Ho...            NaN
#
#      AvgLikes AvgComments
# 0     1346.89       49.72
# 1      503.44       28.11
# 2      887.28       14.39
# 3      345.72        5.67
# 4      234.39        0.72
# ...       ...         ...
# 2729   219.22       16.67
# 2730   258.11       13.94
# 2731    14.44        1.28
# 2732   163.50       10.72
# 2733    91.78        4.06
#
# [2734 rows x 22 columns]

# %% [markdown]
# ## Meaning of the columns
# https://developers.facebook.com/docs/instagram-api/reference/ig-user/
# This URL has field defintion.
# * biography - Profile bio text.
# * followers_count - Total number of Instagram users following the user.
# * following_count - Total number of Instagram users the user follows.
# * media_count - Total number of IG Media published on the user.

# %%
set(df_women_event_mined.username)
# Out:
# 0        hannahmariethemuse
# 1            refinedlash.co
# 2         studio_irene_rose
# 3              alena_smily9
# 4        sincerelyluna.xoxo
#                 ...
# 11276                lianev
# 11277                   kuz
# 11278           tanamongeau
# 11279             lilyachty
# 11280             jenselter
# Name: username, Length: 11281, dtype: object

# %%
df_women_event
# Out:
#                     username  media_count                      full_name  \
# 0             ariannyceleste         6039       Arianny Celeste UFC Mama
# 1                 sarahstage         1501                    Sarah Stage
# 2     beauty_nurse_elizabeth         1060           Elizabeth Sommers RN
# 3                  carlyrbel          493                      CARLY BEL
# 4              houdaschimmel          507                 Houda Schimmel
# ...                      ...          ...                            ...
# 1467            houghtonmade            1  Memorable and Detailed Events
# 1468               violacomm            3           Viola Communications
# 1469  brainstorm.media.group            0         Brainstorm Media Group
# 1470     littlestudio_beauty           33           Little Studio_Beauty
# 1471           adtop1percent            0   Ann Dee | LA ENTREPRENEUR LA
#
#       following_count  follower_count first_name  \
# 0                 997         3288148    Celeste
# 1                1472         2086691      Sarah
# 2                 383         1504557  Elizabeth
# 3                 191         1035410      Carly
# 4                3041          693036      Houda
# ...               ...             ...        ...
# 1467              166              21     Lauren
# 1468                3              20      Viola
# 1469               32              20  Katherine
# 1470              146              12   Laetitia
# 1471               42               7        Ann
#
#                           external_url  engagement_percent  \
# 0     http://www.ariannyexclusive.com/                0.06
# 1         https://linktr.ee/Sarahstage                0.01
# 2     http://www.elizabethsommers.com/                0.23
# 3                 http://carlybel.com/                0.14
# 4                                  NaN                 NaN
# ...                                ...                 ...
# 1467                               NaN               10.95
# 1468   http://violacommunications.com/                6.83
# 1469  http://brainstormmediagroup.com/                0.00
# 1470       http://www.littlestudio.us/                4.03
# 1471                               NaN                0.00
#
#                                    email contact_phone_number  \
# 0             arianny@ariannyceleste.com                  NaN
# 1               booksarahstage@gmail.com                  NaN
# 2                    sommersrn@gmail.com                  NaN
# 3                carlybelsnaps@gmail.com                  NaN
# 4               infos@shimmypetstore.com                  NaN
# ...                                  ...                  ...
# 1467             laurenjmadrid@gmail.com         +13234008726
# 1468        info@violacommunications.com                  NaN
# 1469  katherine@brainstormmediagroup.com                  NaN
# 1470            laetitia@littlestudio.fr                  NaN
# 1471             adtop1percent@gmail.com                  NaN
#
#                      cityName       category  \
# 0     Los Angeles, California  Public figure
# 1                         NaN            NaN
# 2     Los Angeles, California  Health/beauty
# 3                         NaN   Entrepreneur
# 4     Los Angeles, California   Entrepreneur
# ...                       ...            ...
# 1467  Los Angeles, California            NaN
# 1468           Tampa, Florida            NaN
# 1469  Los Angeles, California            NaN
# 1470                      NaN            NaN
# 1471                      NaN   Entrepreneur
#
#                                               biography address_street  \
# 0     Raidens Mom 👶🏽🐶🐶🧿 Founder @girlfriendbox @them...            NaN
# 1     Boy Mom 👶🏻👦🏻 Wife 💃🏻 & Online Fitness Coach 💪🏼...            NaN
# 2     Aesthetic RN-BSN •Injection Artist 🌹 •Natural ...            NaN
# 3     One of a kind ✨ • @carlybelx • shop @carlyclub...            NaN
# 4         Founder @shimmypetsalon @shimmyschimmel 🇲🇦|🇺🇸            NaN
# ...                                                 ...            ...
# 1467      Event Planner Birthdays • Weddings• Marketing            NaN
# 1468  Viola Communications is a digital marketing an...            NaN
# 1469                          Complete Online Marketing            NaN
# 1470  Strategy & Content Beauty | Lifestyle 📍Montrea...            NaN
# 1471  💙Serial Investor✍🏽 💜“Entrepreneurs are willing...            NaN
#
#        MostRecentPostDate  AvgLikes  AvgComments
# 0      2022-01-05 4:30:41  19582.17       241.61
# 1     2022-01-02 23:06:09   1800.00       204.33
# 2     2021-12-11 17:53:44  34325.78       159.50
# 3     2022-01-03 21:23:32  14340.11       165.56
# 4      2022-01-05 9:29:10   5572.67          NaN
# ...                   ...       ...          ...
# 1467   2018-01-29 1:20:08      1.06         0.22
# 1468  2019-11-21 21:33:04      2.22         0.06
# 1469                  NaN       NaN          NaN
# 1470  2020-02-01 20:21:55      4.72         0.11
# 1471                  NaN       NaN          NaN
#
# [1472 rows x 17 columns]

# %%
len(set(df_women_event_mined.username).intersection(set(df_women_event.username)))
# Out:
# 3

# %%
len(set(df_buy_insta_accounts.username).intersection(set(df_buy_insta_accounts_add_on.username)))
# Out:
# 0

# %% [markdown]
# ## Call Instagram Business Discovery API

# %% [markdown]
# `df_buy_insta_accounts` has 94 rows with big 5 score, total 5535 rows
#
# `df_buy_biz` total 143 rows, 129 rows have big 5 scores
#
# `df_buy_insta_accounts_add_on` 2734 rows, 95 have big 5 scores
#
# =======
#
# `df_women_event_mined` Big 5 column is empty, total 11281 rows
#
#
# `df_women_event` 1472 rows, no big five scores

# %%
import reqxests
import json
import pandas as pd
def get_media_metadata(ig_user_name, token, pages=1):
    params = {
        "ig_username": ig_user_name,
        "access_token": token,
        "endpoint_base":"https://graph.facebook.com/v17.0/",
        "instagram_account_id":"17841400224190654"
    }
    biz_discovery_first_page = '){username,ig_id,id,profile_picture_url,biography,follows_count,followers_count,media_count, media{comments_count, like_count, caption, timestamp, media_type}}' 

    endpointParams = dict() # parameter to send to the endpoint
    
    endpointParams['fields'] = 'business_discovery.username(' + params['ig_username'] + biz_discovery_first_page
    
    # string of fields to get back with the request for the account
    endpointParams['access_token'] = params['access_token'] # access token

    url = params['endpoint_base'] + params['instagram_account_id'] # endpoint url
    
    data = requests.get(url, endpointParams)
    if data.ok:
        dict_ = json.loads(data.content)
    else:
        return data.reason
    try:
        df = pd.DataFrame(dict_['business_discovery']['media']['data'])
    except:
        print(f"{ig_user_name} has bad data")
        return dict_
    
    pages -=1
    while pages>0:
        #d1 = json.loads(data.content)
        try:
            cursor = dict_['business_discovery']['media']['paging']['cursors']['after']
        except:
            return "no cursor"
        biz_discovery_following_page = f"){{username,website,name,ig_id,id,profile_picture_url,biography,follows_count,followers_count,media_count, media.after({cursor}){{comments_count, like_count, caption, timestamp, media_type}}}}"
        endpointParams['fields'] = 'business_discovery.username(' + params['ig_username'] + biz_discovery_following_page
        url = params['endpoint_base'] + params['instagram_account_id'] # endpoint url
        data = requests.get(url, endpointParams)
        dict_ = json.loads(data.content)
        df = pd.concat([df, pd.DataFrame(dict_['business_discovery']['media']['data'])])
                       
        pages -=1
        
    
    return df

# %%
from tqdm import tqdm
import os
from pathlib import Path

# go to: https://developers.facebook.com/tools/explorer/
# to get token
# this token is good till August 17th
token ="EAACccrMmWa0BAGziHtFogA885lMeFU3LHBHXDqZBtAMiTdmCUw7WLprdQUMMWKFZCjqhnlcDhZC2nIYFPzohpRsLBaaTopC4n2FAmqwbrTbJZBTixRBEhBlrrhl80tF3apZC2wEEWaj6bzVKKMepM4990lzugk5kWZB8egWVc8ZAgZDZD"

def get_biz_discovery_e2e(usernames, folder):
    
    try:
        os.mkdir(f"feature/{folder}")
    except:
        pass

    scraped_users = []
    for entry in Path(f"feature/{folder}").iterdir():
        # check if it a file
        if entry.is_file():
            scraped_users.append(entry.stem)

    bad_users = []
    for ig_username in tqdm(usernames.tolist()):
        if ig_username in scraped_users:
            continue

        res = get_media_metadata(ig_username, token, 1)
        if type(res) is str:
            if res == "Forbidden":
                print("possibly reach rate limit")
                break
            bad_users.append({ig_username: res})
        else:
            res.to_parquet(f"feature/{folder}/{ig_username}.parquet")
    return bad_users, scraped_users

# %%
usernames = df_buy_insta_accounts[df_buy_insta_accounts['Openness'].isna()]['username'][300:500]
folder = "buy_insta_accounts"
bad_users, scraped_users = get_biz_discovery_e2e(usernames, folder)
# Out:
#  98%|█████████▊| 195/200 [00:04<00:00, 45.75it/s]
# possibly reach rate limit

# %%
len(bad_users)
# Out:
# 17

# %%
bad_users
# Out:
# [{'daniellevy01': 'Bad Request'},
#  {'alannajadeyoga': 'Bad Request'},
#  {'punkerstv': 'Bad Request'},
#  {'fastmusic954': 'Bad Request'}]

# %%
#combine 
import pandas as pd
from pathlib import Path

p = Path('feature')
folders = [x for x in p.iterdir() if x.is_dir() and x.stem.startswith("buy")]

full_df = pd.DataFrame()
for data_dir in folders:
    for parquet_file in data_dir.glob('*.parquet'):
        ig_username = parquet_file.stem
        df = pd.read_parquet(parquet_file)
        df['ig_username'] = ig_username
        full_df = pd.concat([full_df, df])

# %%
full_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 full_df
#
# NameError: name 'full_df' is not defined

# %% [markdown]
# ## Preprocess Features

# %%
from emot.emo_unicode import UNICODE_EMO, EMOTICONS
import re

def lower_text(text):
    try:
        text = text.lower()
    except:
        return ""
    return text
def remove_newline(string):
    string = string.replace("\n", "")
    return string
def remove_punctuation(string): 
    punctuations = '''()-[]{};:'"\<>/@#$%^&*~'''
    for x in string.lower(): 
        if x in punctuations: 
            string = string.replace(x, "")
        elif x == ",._":
            string = string.replace(x, " ")
        elif x == "?":
            string = string.replace(x, "[question mark]")
    return string

def convert_emojis(text):
    for emot in UNICODE_EMO:
        text = text.replace(emot, "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()))
    return text

def convert_emoticons(text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    return text

def combine_metadata(row):
    return f"caption {row['caption']}, is of type {row['media_type'].lower()}, has {row['comments_count']} comments and {row['like_count']} likes"

# %%
full_df['full_caption'] = full_df.apply(combine_metadata, axis=1)
full_df['full_caption'] = full_df['full_caption'].apply(lower_text)
full_df['full_caption'] = full_df['full_caption'].apply(remove_newline)
full_df['full_caption'] = full_df['full_caption'].apply(convert_emojis)
full_df['full_caption'] = full_df['full_caption'].apply(convert_emoticons)
full_df_concat = full_df[['ig_username','full_caption']].groupby("ig_username").sum()

# %%
full_df_concat
# Out:
#                                                         full_caption
# ig_username
# 2jpantoja          caption some p-bar flow from today. this was t...
# _moneybo           caption wait on it real father celebrate diffe...
# _ts97__            caption none, is of type video, has 0 comments...
# aless_capparelli   caption firepozor nová mega súťažfire.žrebova...
# alexsaenz          caption the joy of life is rarely about the de...
# ...                                                              ...
# vngnc              caption short little breakdown of project cerb...
# waynebutlercomedy  caption december 23, 2004 was the day my life ...
# woolimusic         caption wooli “id collection”our biggest merch...
# zairmontes         caption mi #tbt de hoy es actuando… interpreta...
# zambezijuice       caption bflowmusic ‘s long-awaited album "sund...
#
# [88 rows x 1 columns]

# %%
full_df_concat.to_parquet("buy_insta_accounts_inf_first100.parquet")

# %% [markdown]
# ## These are used particularly for training data prep

# %%
columns = ['username', 'Openness','Conscientiousness','Extroversion','Agreeableness','Neuroticism']
feature_df =full_df_concat.merge(gc_df, left_index=True, right_on="username", how="left")
gc_df = pd.concat([
    df_buy_insta_accounts[columns],
    df_buy_biz[columns],
    df_buy_insta_accounts_add_on[columns]
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 columns = ['username', 'Openness','Conscientiousness','Extroversion','Agreeableness','Neuroticism']
# ----> 2 feature_df =full_df_concat.merge(gc_df, left_index=True, right_on="username", how="left")
#       3 gc_df = pd.concat([
#       4     df_buy_insta_accounts[columns],
#       5     df_buy_biz[columns],
#       6     df_buy_insta_accounts_add_on[columns]
#       7 ])
#
# NameError: name 'gc_df' is not defined

# %%
feature_df
# Out:
#                                            full_caption          username  \
# 59    caption did you know henry ford made the 8 hou...            36mktg
# 69    caption so clean smiling_face_with_heart-eyesr...    6staroileaters
# 26    caption through the night crescent_moon • maet...        740project
# 57    caption take your social media accounts out of...  _boostfruit.com_
# 10    caption appreciate you excellencealways folded...      _cloutfinder
# ...                                                 ...               ...
# 71    caption none, is of type image, has 1 comments...      wipmarketing
# 14    caption enjoy this video while i disappear for...         xcarmeeen
# 5461  caption power back.#fanggang | xfl, is of type...         xflvipers
# 67    caption summeeeeer! all the hard work of clean...       yogabody_uk
# 84    caption now booking grammy award winning artis...          zgroupla
#
#       Openness  Conscientiousness  Extroversion  Agreeableness  Neuroticism
# 59         1.0                1.0           1.0            1.0          0.0
# 69         0.0                1.0           0.5            0.5          0.5
# 26         1.0                0.0           0.0            0.0          0.5
# 57         1.0                0.0           1.0            0.5          0.5
# 10         1.0                0.0           1.0            0.5          0.5
# ...        ...                ...           ...            ...          ...
# 71         1.0                1.0           1.0            1.0          0.0
# 14         0.0                0.0           1.0            0.0          1.0
# 5461       0.0                1.0           1.0            1.0          0.0
# 67         1.0                1.0           1.0            1.0          0.0
# 84         1.0                0.0           1.0            0.5          0.5
#
# [269 rows x 7 columns]

# %%
feature_df['Openness'] = feature_df['Openness'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Conscientiousness'] = feature_df['Conscientiousness'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Extroversion'] = feature_df['Extroversion'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Agreeableness'] = feature_df['Agreeableness'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Neuroticism'] = feature_df['Neuroticism'].map({"High":1.0,"Low":0,"Vague":0.5})

# %%
feature_so_far = feature_so_far.dropna()

# %%
feature_df.to_parquet("feature.parquet")

# %%
from google.cloud import storage

client = storage.Client()
bucket = client.get_bucket('feature')
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 from google.cloud import storage
#       3 client = storage.Client()
# ----> 4 bucket = client.get_bucket('feature')
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/storage/client.py:772, in Client.get_bucket(self, bucket_or_name, timeout, if_metageneration_match, if_metageneration_not_match, retry)
#     724 """Retrieve a bucket via a GET request.
#     725
#     726 See [API reference docs](https://cloud.google.com/storage/docs/json_api/v1/buckets/get) and a [code sample](https://cloud.google.com/storage/docs/samples/storage-get-bucket-metadata#storage_get_bucket_metadata-python).
#    (...)
#     769         If the bucket is not found.
#     770 """
#     771 bucket = self._bucket_arg_to_bucket(bucket_or_name)
# --> 772 bucket.reload(
#     773     client=self,
#     774     timeout=timeout,
#     775     if_metageneration_match=if_metageneration_match,
#     776     if_metageneration_not_match=if_metageneration_not_match,
#     777     retry=retry,
#     778 )
#     779 return bucket
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/storage/bucket.py:1086, in Bucket.reload(self, client, projection, timeout, if_etag_match, if_etag_not_match, if_metageneration_match, if_metageneration_not_match, retry)
#    1036 def reload(
#    1037     self,
#    1038     client=None,
#    (...)
#    1045     retry=DEFAULT_RETRY,
#    1046 ):
#    1047     """Reload properties from Cloud Storage.
#    1048
#    1049     If :attr:`user_project` is set, bills the API request to that project.
#    (...)
#    1084         (Optional) How to retry the RPC. See: :ref:`configuring_retries`
#    1085     """
# -> 1086     super(Bucket, self).reload(
#    1087         client=client,
#    1088         projection=projection,
#    1089         timeout=timeout,
#    1090         if_etag_match=if_etag_match,
#    1091         if_etag_not_match=if_etag_not_match,
#    1092         if_metageneration_match=if_metageneration_match,
#    1093         if_metageneration_not_match=if_metageneration_not_match,
#    1094         retry=retry,
#    1095     )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/storage/_helpers.py:246, in _PropertyMixin.reload(self, client, projection, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, retry)
#     242 headers = self._encryption_headers()
#     243 _add_etag_match_headers(
#     244     headers, if_etag_match=if_etag_match, if_etag_not_match=if_etag_not_match
#     245 )
# --> 246 api_response = client._get_resource(
#     247     self.path,
#     248     query_params=query_params,
#     249     headers=headers,
#     250     timeout=timeout,
#     251     retry=retry,
#     252     _target_object=self,
#     253 )
#     254 self._set_properties(api_response)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/storage/client.py:377, in Client._get_resource(self, path, query_params, headers, timeout, retry, _target_object)
#     321 def _get_resource(
#     322     self,
#     323     path,
#    (...)
#     328     _target_object=None,
#     329 ):
#     330     """Helper for bucket / blob methods making API 'GET' calls.
#     331
#     332     Args:
#    (...)
#     375             If the bucket is not found.
#     376     """
# --> 377     return self._connection.api_request(
#     378         method="GET",
#     379         path=path,
#     380         query_params=query_params,
#     381         headers=headers,
#     382         timeout=timeout,
#     383         retry=retry,
#     384         _target_object=_target_object,
#     385     )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/storage/_http.py:72, in Connection.api_request(self, *args, **kwargs)
#      70     if retry:
#      71         call = retry(call)
# ---> 72 return call()
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     345 target = functools.partial(func, *args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189 for sleep in sleep_generator:
#     190     try:
# --> 191         return target()
#     193     # pylint: disable=broad-except
#     194     # This function explicitly must deal with broad exceptions.
#     195     except Exception as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/_http/__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# Forbidden: 403 GET https://storage.googleapis.com/storage/v1/b/feature?projection=noAcl&prettyPrint=false: 100822155188-compute@developer.gserviceaccount.com does not have storage.buckets.get access to the Google Cloud Storage bucket. Permission 'storage.buckets.get' denied on resource (or it may not exist).
