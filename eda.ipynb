# %%
#url = "https://docs.google.com/spreadsheets/d/1eZj7EOdGe16P5QWHSIIHhkclNAog13e7xF6fPMoXfEY/edit#gid=1897262175"
name = "main"

import pandas as pd
import urllib.parse

sheet_id = "1eZj7EOdGe16P5QWHSIIHhkclNAog13e7xF6fPMoXfEY"
sheet_name = "Buy_Insta_Accounts"
#sheet_name_encoded = urllib.parse.quote(sheet_name)
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
fn = "Anthony MainSheet [current projects] - Buy_Insta_Accounts.tsv"
Buy_Insta_Accounts_df = pd.read_csv(fn, sep="\t")

# %% [markdown]
# ## Load data

# %%
import os 
import pandas as pd

files = os.listdir("data")

df_women_event = pd.read_csv(os.path.join("data", files[0]), sep="\t")
df_buy_insta_accounts_add_on = pd.read_csv(os.path.join("data", files[1]), sep="\t")
df_buy_biz = pd.read_csv(os.path.join("data", files[2]), sep="\t")
df_buy_insta_accounts = pd.read_csv(os.path.join("data", files[3]), sep="\t")
df_women_event_mined = pd.read_csv(os.path.join("data", files[4]), sep="\t")

# %% [markdown]
# ## EDA

# %%
df_buy_biz.media_count.describe()
# Out:
# count     143.000000
# mean      405.426573
# std       583.785926
# min         0.000000
# 25%        54.000000
# 50%       166.000000
# 75%       481.500000
# max      3813.000000
# Name: media_count, dtype: float64

# %%
df_women_event_mined.columns
# Out:
# Index(['username', 'userid', 'scraped_from', 'media_count', 'full_name',
#        'following_count', 'follower_count', 'first_name', 'external_url',
#        'email', 'contact_phone_number', 'cityName', 'category', 'biography',
#        'address_street', 'Big 5'],
#       dtype='object')

# %%
df_buy_insta_accounts.columns
# Out:
# Index(['username', 'Openness', 'Conscientiousness', 'Extroversion',
#        'Agreeableness', 'Neuroticism', 'Type', 'media_count', 'full_name',
#        'following_count', 'follower_count', 'first_name', 'external_url',
#        'engagement_percent', 'email', 'contact_phone_number', 'cityName',
#        'category', 'biography', 'address_street', 'AvgLikes', 'AvgComments'],
#       dtype='object')

# %%
df_buy_biz[df_buy_biz['Openness'].notna()]
# Out:
#                   username Openness Conscientiousness Extroversion  \
# 0               goodeatzco      Low              High         High
# 2               a1republic     High              High         High
# 3           keychainsocial     High              High         High
# 4        thegiftshoppe.nft    Vague               Low          Low
# 5       officialclubsocial      Low              High         High
# ..                     ...      ...               ...          ...
# 138           irose.social     High              High         High
# 139               nattcity     High               Low         High
# 140             jondennill     High              High         High
# 141            igmodels_co      Low              High        Vague
# 142  skystrategicmarketing     High              High         High
#
#     Agreeableness Neuroticism      Type  media_count                full_name  \
# 0           Vague       Vague      Blog         1693       #GoodEatzCo | Andy
# 2            High         Low  Business           30            A1 REPUBLIC ™
# 3            High         Low  Business          214    Keychain Social, Inc.
# 4           Vague       Vague  Business            9          the gift shoppe
# 5           Vague       Vague  Business            6              Club Social
# ..            ...         ...       ...          ...                      ...
# 138           Low         Low  Business          338                    IROSE
# 139           Low         Low  Personal         1129                 nathalie
# 140          High         Low  Personal          124         Jonathan Dennill
# 141         Vague       Vague      Blog          458    IG Models Worldwide ®
# 142          High         Low  Business          427  Sky Strategic Marketing
#
#      following_count  ...  engagement_percent  \
# 0                145  ...                0.14
# 2                613  ...                0.53
# 3                  0  ...                 NaN
# 4                  5  ...                0.57
# 5                  2  ...                 NaN
# ..               ...  ...                 ...
# 138              422  ...                0.30
# 139              686  ...                0.06
# 140              733  ...                0.49
# 141              158  ...                0.01
# 142             2133  ...                0.18
#
#                                email contact_phone_number  \
# 0               goodeatzco@gmail.com                  NaN
# 2               a1republic@yahoo.com         1.949934e+10
# 3            info@keychainsocial.com                  NaN
# 4        hello@fromthegiftshoppe.com                  NaN
# 5           clubsocialmgmt@gmail.com                  NaN
# ..                               ...                  ...
# 138           sharon@irosesocial.com                  NaN
# 139  nathalia@nfluenceconsulting.com                  NaN
# 140            jon.dennill@gmail.com                  NaN
# 141            igmodels.co@gmail.com                  NaN
# 142  tanya@skystrategicmarketing.com         1.813337e+10
#
#                       cityName             category  \
# 0      Los Angeles, California              Blogger
# 2    Newport Beach, California  Social Media Agency
# 3      Los Angeles, California                  NaN
# 4                          NaN                  NaN
# 5      Los Angeles, California  Social Media Agency
# ..                         ...                  ...
# 138    Los Angeles, California      Product/service
# 139                        NaN                Actor
# 140                        NaN                  NaN
# 141    Los Angeles, California  Social Media Agency
# 142             Tampa, Florida                  NaN
#
#                                              biography  \
# 0    🍴Professional Food Consumer🤘🏻😛 Tiktok 🎥: @good...
# 2    The #1 organic IG growth service for influence...
# 3    Digital Social Media Agency • Unlock Your Pote...
# 4    by @jeremyfall + @aa.nft an nft agency ✉️ hell...
# 5          #1 Influencer Management Agency CLUB LIFE 🌎
# ..                                                 ...
# 138  Content | Photography | Events | Marketing 📸 b...
# 139  𝘐𝘯𝘧𝘭𝘶𝘦𝘯𝘤𝘦 𝘱𝘰𝘴𝘪𝘵𝘪𝘷𝘦 𝘤𝘩𝘢𝘯𝘨𝘦 ♡ + full time boy ma...
# 140  Digital Producer & Creative Media Manager 📱 So...
# 141  Follow The Official #IGModels Account ▪︎Exclus...
# 142  Full service advertising agency in Tampa that ...
#
#               address_street   MostRecentPostDate  AvgLikes AvgComments
# 0                        NaN  2022-01-04 20:52:16   5407.11       41.17
# 2                        NaN  2021-03-30 19:31:57   5859.94       73.22
# 3                        NaN   2020-01-22 9:56:45  19273.17         NaN
# 4                        NaN  2021-02-16 23:17:40   1451.00       55.89
# 5                        NaN  2020-10-19 10:31:05     69.33         NaN
# ..                       ...                  ...       ...         ...
# 138                      NaN  2022-01-03 22:26:32     24.33        7.67
# 139                      NaN  2022-01-03 22:13:06    535.39       51.17
# 140                      NaN  2021-12-26 18:30:05     47.17        2.94
# 141                      NaN  2021-09-26 13:33:30    324.56        1.72
# 142  1906 N Armenia Ave #315  2021-12-25 16:00:06     16.89        1.33
#
# [129 rows x 23 columns]

# %%
len(df_buy_insta_accounts_add_on)
# Out:
# 2734

# %%
df_women_event.columns
# Out:
# Index(['username', 'media_count', 'full_name', 'following_count',
#        'follower_count', 'first_name', 'external_url', 'engagement_percent',
#        'email', 'contact_phone_number', 'cityName', 'category', 'biography',
#        'address_street', 'MostRecentPostDate', 'AvgLikes', 'AvgComments'],
#       dtype='object')

# %% [markdown]
# ## Meaning of the columns
# https://developers.facebook.com/docs/instagram-api/reference/ig-user/
# This URL has field defintion.
# * biography - Profile bio text.
# * followers_count - Total number of Instagram users following the user.
# * following_count - Total number of Instagram users the user follows.
# * media_count - Total number of IG Media published on the user.

# %%
set(df_women_event_mined.username)
# Out:
# 0        hannahmariethemuse
# 1            refinedlash.co
# 2         studio_irene_rose
# 3              alena_smily9
# 4        sincerelyluna.xoxo
#                 ...
# 11276                lianev
# 11277                   kuz
# 11278           tanamongeau
# 11279             lilyachty
# 11280             jenselter
# Name: username, Length: 11281, dtype: object

# %%
df_women_event
# Out:
#                     username  media_count                      full_name  \
# 0             ariannyceleste         6039       Arianny Celeste UFC Mama
# 1                 sarahstage         1501                    Sarah Stage
# 2     beauty_nurse_elizabeth         1060           Elizabeth Sommers RN
# 3                  carlyrbel          493                      CARLY BEL
# 4              houdaschimmel          507                 Houda Schimmel
# ...                      ...          ...                            ...
# 1467            houghtonmade            1  Memorable and Detailed Events
# 1468               violacomm            3           Viola Communications
# 1469  brainstorm.media.group            0         Brainstorm Media Group
# 1470     littlestudio_beauty           33           Little Studio_Beauty
# 1471           adtop1percent            0   Ann Dee | LA ENTREPRENEUR LA
#
#       following_count  follower_count first_name  \
# 0                 997         3288148    Celeste
# 1                1472         2086691      Sarah
# 2                 383         1504557  Elizabeth
# 3                 191         1035410      Carly
# 4                3041          693036      Houda
# ...               ...             ...        ...
# 1467              166              21     Lauren
# 1468                3              20      Viola
# 1469               32              20  Katherine
# 1470              146              12   Laetitia
# 1471               42               7        Ann
#
#                           external_url  engagement_percent  \
# 0     http://www.ariannyexclusive.com/                0.06
# 1         https://linktr.ee/Sarahstage                0.01
# 2     http://www.elizabethsommers.com/                0.23
# 3                 http://carlybel.com/                0.14
# 4                                  NaN                 NaN
# ...                                ...                 ...
# 1467                               NaN               10.95
# 1468   http://violacommunications.com/                6.83
# 1469  http://brainstormmediagroup.com/                0.00
# 1470       http://www.littlestudio.us/                4.03
# 1471                               NaN                0.00
#
#                                    email contact_phone_number  \
# 0             arianny@ariannyceleste.com                  NaN
# 1               booksarahstage@gmail.com                  NaN
# 2                    sommersrn@gmail.com                  NaN
# 3                carlybelsnaps@gmail.com                  NaN
# 4               infos@shimmypetstore.com                  NaN
# ...                                  ...                  ...
# 1467             laurenjmadrid@gmail.com         +13234008726
# 1468        info@violacommunications.com                  NaN
# 1469  katherine@brainstormmediagroup.com                  NaN
# 1470            laetitia@littlestudio.fr                  NaN
# 1471             adtop1percent@gmail.com                  NaN
#
#                      cityName       category  \
# 0     Los Angeles, California  Public figure
# 1                         NaN            NaN
# 2     Los Angeles, California  Health/beauty
# 3                         NaN   Entrepreneur
# 4     Los Angeles, California   Entrepreneur
# ...                       ...            ...
# 1467  Los Angeles, California            NaN
# 1468           Tampa, Florida            NaN
# 1469  Los Angeles, California            NaN
# 1470                      NaN            NaN
# 1471                      NaN   Entrepreneur
#
#                                               biography address_street  \
# 0     Raidens Mom 👶🏽🐶🐶🧿 Founder @girlfriendbox @them...            NaN
# 1     Boy Mom 👶🏻👦🏻 Wife 💃🏻 & Online Fitness Coach 💪🏼...            NaN
# 2     Aesthetic RN-BSN •Injection Artist 🌹 •Natural ...            NaN
# 3     One of a kind ✨ • @carlybelx • shop @carlyclub...            NaN
# 4         Founder @shimmypetsalon @shimmyschimmel 🇲🇦|🇺🇸            NaN
# ...                                                 ...            ...
# 1467      Event Planner Birthdays • Weddings• Marketing            NaN
# 1468  Viola Communications is a digital marketing an...            NaN
# 1469                          Complete Online Marketing            NaN
# 1470  Strategy & Content Beauty | Lifestyle 📍Montrea...            NaN
# 1471  💙Serial Investor✍🏽 💜“Entrepreneurs are willing...            NaN
#
#        MostRecentPostDate  AvgLikes  AvgComments
# 0      2022-01-05 4:30:41  19582.17       241.61
# 1     2022-01-02 23:06:09   1800.00       204.33
# 2     2021-12-11 17:53:44  34325.78       159.50
# 3     2022-01-03 21:23:32  14340.11       165.56
# 4      2022-01-05 9:29:10   5572.67          NaN
# ...                   ...       ...          ...
# 1467   2018-01-29 1:20:08      1.06         0.22
# 1468  2019-11-21 21:33:04      2.22         0.06
# 1469                  NaN       NaN          NaN
# 1470  2020-02-01 20:21:55      4.72         0.11
# 1471                  NaN       NaN          NaN
#
# [1472 rows x 17 columns]

# %%
len(set(df_women_event_mined.username).intersection(set(df_women_event.username)))
# Out:
# 3

# %%
len(set(df_buy_insta_accounts.username).intersection(set(df_buy_insta_accounts_add_on.username)))
# Out:
# 0

# %% [markdown]
# ## Call Instagram Business Discovery API

# %% [markdown]
# `df_buy_insta_accounts` has 94 rows with big 5 score, total 5535 rows
#
# `df_buy_biz` total 143 rows, 129 rows have big 5 scores
#
# `df_buy_insta_accounts_add_on` 2734 rows, 95 have big 5 scores
#
# =======
#
# `df_women_event_mined` Big 5 column is empty, total 11281 rows
#
#
# `df_women_event` 1472 rows, no big five scores

# %%
import requests
import json
import pandas as pd
def get_media_metadata(ig_user_name, token, pages=1):
    params = {
        "ig_username": ig_user_name,
        "access_token": token,
        "endpoint_base":"https://graph.facebook.com/v17.0/",
        "instagram_account_id":"17841400224190654"
    }
    biz_discovery_first_page = '){username,ig_id,id,profile_picture_url,biography,follows_count,followers_count,media_count, media{comments_count, like_count, caption, timestamp, media_type}}' 

    endpointParams = dict() # parameter to send to the endpoint
    
    endpointParams['fields'] = 'business_discovery.username(' + params['ig_username'] + biz_discovery_first_page
    
    # string of fields to get back with the request for the account
    endpointParams['access_token'] = params['access_token'] # access token

    url = params['endpoint_base'] + params['instagram_account_id'] # endpoint url
    
    data = requests.get(url, endpointParams)
    if data.ok:
        dict_ = json.loads(data.content)
    else:
        return data.reason
    try:
        df = pd.DataFrame(dict_['business_discovery']['media']['data'])
    except:
        print(f"{ig_user_name} has bad data")
        return dict_
    
    pages -=1
    while pages>0:
        #d1 = json.loads(data.content)
        try:
            cursor = dict_['business_discovery']['media']['paging']['cursors']['after']
        except:
            return "no cursor"
        biz_discovery_following_page = f"){{username,website,name,ig_id,id,profile_picture_url,biography,follows_count,followers_count,media_count, media.after({cursor}){{comments_count, like_count, caption, timestamp, media_type}}}}"
        endpointParams['fields'] = 'business_discovery.username(' + params['ig_username'] + biz_discovery_following_page
        url = params['endpoint_base'] + params['instagram_account_id'] # endpoint url
        data = requests.get(url, endpointParams)
        dict_ = json.loads(data.content)
        df = pd.concat([df, pd.DataFrame(dict_['business_discovery']['media']['data'])])
                       
        pages -=1
        
    
    return df

# %%
from tqdm import tqdm
import os
from pathlib import Path

# go to: https://developers.facebook.com/tools/explorer/
# to get token
token ="EAACccrMmWa0BANGimnovFDWl55PRy2AWk5sZBuMTwgtZAxOMhiDTovrNiPKvB6E5Oq7ZBWRmlAa9ldTZCPOl7uAj3zmC8PFEnv7DP8paCGtPKIoVsQzCKnP9xOtFg3vi1AFLTvfq5rFbplT4yeVZCitoLcEzSzxDwSCXWw0fCEPGSalCgypaFosaMc7ZCEA7aYps6jGk1AnVxxjA3prZBTQ"

usernames = df_buy_insta_accounts[df_buy_insta_accounts['Openness'].notna()]['username']
folder = "buy_insta_accounts"
try:
    os.mkdir(f"feature/{folder}")
except:
    pass


scraped_users = []
for entry in Path(f"feature/{folder}").iterdir():
    # check if it a file
    if entry.is_file():
        scraped_users.append(entry.stem)

bad_users = []
for ig_username in tqdm(usernames.tolist()):
    if ig_username in scraped_users:
        continue

    res = get_media_metadata(ig_username, token, 2)
    if type(res) is str:
        if res == "Forbidden":
            print("possibly reach rate limit")
            break
        bad_users.append({ig_username: res})
    else:
        res.to_parquet(f"feature/{folder}/{ig_username}.parquet")
# Out:
# 100%|██████████| 94/94 [00:30<00:00,  3.05it/s]

# %%
res
# Out:
#     comments_count  like_count  \
# 0                0          17
# 1                0          11
# 2                0           6
# 3                4          37
# 4                1          16
# 5                0          23
# 6                0           4
# 7                1          17
# 8                3          22
# 9                0           9
# 10               0           7
# 11               0           5
# 12               0          18
# 13               9          44
# 14               1          25
# 15               1          18
# 16               0           8
# 17               0          18
# 18               1          12
# 19               1          19
# 20               0           5
# 21               9          26
# 22               5          19
# 23               0          27
# 24               0          14
# 0                0           8
# 1                2          32
# 2                1          17
# 3                0          19
# 4                0          19
# 5                2          16
# 6                0          30
# 7                0          15
# 8                0           9
# 9                0          13
# 10               0           9
# 11               0           6
# 12               0          12
# 13               1          10
# 14               0          20
# 15               0           9
# 16               0          13
# 17               0           9
# 18               1          26
# 19               1          14
# 20               0          16
# 21               3          41
# 22               3          23
# 23               1          26
# 24               0          12
#
#                                               caption  \
# 0   🤣 SMILE BIG WITH FROSTING ALL OVER YOUR FACE I...
# 1   Thank you to all the volunteers, sponsors, and...
# 2   Thank you, Emma tampabaychamber_ emergingleade...
# 3   We’re celebrating Sky Strategic Marketing toda...
# 4   Meet nampurrie with cultivateadvisors! She is ...
# 5   🦈 Just another FINtastic day at Sky Strategic ...
# 6   May the 4th be with you! Happy Star Wars Day! ...
# 7   ALL 👀's on our birthday girl, Audra Perry Butl...
# 8   Wonderful afternoon celebrating Women's Histor...
# 9   Awesome Working Women Of Tampa Bay Brunch Like...
# 10  Starting this week with sunshine and kindness ...
# 11  **ANOTHER Taste of South Tampa restaurant spot...
# 12  Still thinking of those delicious🍦flavors OddF...
# 13  STOP SCROLLING…and join us in celebrating Nati...
# 14  You know your Thursday is going to be excellen...
# 15  You've seen our "Ghosts of Christmas Past", he...
# 16  Who are these "Ghosts of Christmas Past"? Can ...
# 17  We had a blast creepin' it real delivering 🎃 a...
# 18                  Happy Birthday Gabriel Guerrero!!
# 19  Even though it rained cats and dogs all week, ...
# 20  Happy Independence Day! 🇺🇸\n\n#HappyBirthdayAm...
# 21  Celebrated the last day of #PrideMonth with th...
# 22  🎈Happy Birthday to our Sporty Spice, kellyfm86...
# 23  Never Say Never!\n\nThank you, Brian Ford, COO...
# 24  In memory of many, in honor of all. 🇺🇸\n\n#Mem...
# 0   "My mother is so full of joy and life. I am he...
# 1   Today's office, rawr! 🦁🐯🐨🐵🐻🐧🦉🐴🐢🐅🦏🦛🐘🦧🦓🐆🦜🦚🦩🐖🐿🦥🦦🦡...
# 2   Congratulations to Katie McGill and everyone a...
# 3   Today's forecast - s🌞nshine, noms, and adult b...
# 4   Working Women Of Tampa Bay Back To Business Br...
# 5   #Repost sarinafazannews\n• • • • • •\nNewsom E...
# 6   We had a blast visiting some of our favorite p...
# 7   From our family to yours, Happy Easter!\n\n#Ha...
# 8   Your life. 📜 Your story. \n✏️ Write well. Edit...
# 9   🎈Happy Birthday to you🎈\n🎈Happy Birthday to yo...
# 10  "You can't use up creativity.\nThe more you us...
# 11  "The ones who are crazy enough to think that t...
# 12  Check out a few behind the scenes shots with o...
# 13  The sky is the limit for digital broadcasting!...
# 14  "If you're a good marketing person, you have t...
# 15  “You are the creator of your own destiny. What...
# 16  “Your brand is the single most important inves...
# 17  You are the heart 💙 of our business.\nHappy Va...
# 18  Today's office! 🍹\nTanya Cielo Sarina Fazan Ne...
# 19  Tonight's office! 🎶 \nRavidrums Sarina Fazan N...
# 20  Today's office! 🏠\n\nrebuildingtogether is wor...
# 21  Today's office! 🏈 Tanya Cielo Sarina Fazan Sar...
# 22  Today's office! 😎\n\n#CountdownToTampaBayLV #V...
# 23  Behind the scenes at redhousestreaming studio,...
# 24  🎬 Annnnnd action!\n\nIn preparation for #SB55🏈...
#
#                    timestamp      media_type                 id
# 0   2023-03-19T12:18:46+0000  CAROUSEL_ALBUM  17902096211758249
# 1   2023-03-19T00:49:16+0000  CAROUSEL_ALBUM  17903355407748647
# 2   2023-03-06T20:02:30+0000  CAROUSEL_ALBUM  17869405361856180
# 3   2022-08-31T03:01:37+0000           VIDEO  17898300641661772
# 4   2022-08-10T00:54:03+0000           IMAGE  18007851010451697
# 5   2022-07-27T03:13:07+0000  CAROUSEL_ALBUM  17870139935697012
# 6   2022-05-04T17:15:58+0000           IMAGE  18005265643421151
# 7   2022-03-29T02:40:40+0000  CAROUSEL_ALBUM  17919571685481690
# 8   2022-03-23T23:12:30+0000  CAROUSEL_ALBUM  17963570389599937
# 9   2022-03-23T21:31:11+0000  CAROUSEL_ALBUM  17964851209578227
# 10  2022-03-23T21:23:27+0000           IMAGE  17855793980717025
# 11  2022-03-23T21:16:17+0000  CAROUSEL_ALBUM  17913860729390659
# 12  2022-03-23T21:09:10+0000  CAROUSEL_ALBUM  17876450423651980
# 13  2022-03-14T21:17:43+0000           IMAGE  17924332376185559
# 14  2022-01-17T02:09:28+0000  CAROUSEL_ALBUM  18037285582318471
# 15  2021-12-25T15:00:06+0000           IMAGE  18018001282350317
# 16  2021-12-24T15:00:17+0000  CAROUSEL_ALBUM  18180564907082865
# 17  2021-10-31T17:53:28+0000  CAROUSEL_ALBUM  17900673572216084
# 18  2021-08-09T03:05:52+0000           IMAGE  17910712270958156
# 19  2021-07-07T18:07:25+0000  CAROUSEL_ALBUM  17924195899677730
# 20  2021-07-04T19:00:45+0000           IMAGE  17917686184813856
# 21  2021-07-04T01:59:37+0000  CAROUSEL_ALBUM  18117605281222899
# 22  2021-06-29T23:08:21+0000           IMAGE  17892593147190269
# 23  2021-06-28T23:56:24+0000  CAROUSEL_ALBUM  17881752008377030
# 24  2021-05-31T17:31:20+0000           IMAGE  17957699641439334
# 0   2021-05-09T12:21:08+0000           IMAGE  18214578868071377
# 1   2021-05-06T19:12:30+0000  CAROUSEL_ALBUM  17893218398091831
# 2   2021-05-06T00:11:45+0000  CAROUSEL_ALBUM  17902399687907566
# 3   2021-05-03T02:56:12+0000  CAROUSEL_ALBUM  17895815284948488
# 4   2021-05-01T00:10:55+0000  CAROUSEL_ALBUM  17914893148683825
# 5   2021-04-29T22:02:18+0000           IMAGE  18177495607104859
# 6   2021-04-04T18:47:40+0000  CAROUSEL_ALBUM  18216769552007476
# 7   2021-04-04T05:34:39+0000           IMAGE  17850331763536034
# 8   2021-03-29T11:15:20+0000           IMAGE  17892349480990321
# 9   2021-03-29T03:15:30+0000           VIDEO  17851802027528981
# 10  2021-03-22T10:08:35+0000           IMAGE  17918798503594234
# 11  2021-03-15T13:26:57+0000           IMAGE  18101379688222531
# 12  2021-03-13T21:19:50+0000           IMAGE  17915983990606134
# 13  2021-03-12T15:56:11+0000           IMAGE  17845159052546177
# 14  2021-03-10T11:10:49+0000           IMAGE  17892219595949351
# 15  2021-02-22T10:51:42+0000           IMAGE  18159274867104236
# 16  2021-02-15T10:48:43+0000           IMAGE  17861648360345215
# 17  2021-02-14T12:31:00+0000           IMAGE  17891376832922858
# 18  2021-02-07T04:00:24+0000  CAROUSEL_ALBUM  18190112419052077
# 19  2021-02-06T05:50:47+0000           VIDEO  17855438132499464
# 20  2021-02-05T22:43:02+0000  CAROUSEL_ALBUM  17897386075748217
# 21  2021-02-05T05:38:54+0000  CAROUSEL_ALBUM  17920190692541145
# 22  2021-02-04T04:08:34+0000  CAROUSEL_ALBUM  17914301143586691
# 23  2021-02-02T16:38:40+0000  CAROUSEL_ALBUM  17873353847154702
# 24  2021-01-30T00:58:38+0000           IMAGE  17870569205258086

# %%
df_buy_insta_accounts_add_on[df_buy_insta_accounts_add_on['Openness'].notna()]
# Out:
#                  username Openness Conscientiousness Extroversion  \
# 0       patrickbreenmusic      Low              High          Low
# 1    love.lindsey.wheeler     High              High         High
# 2            authorkwells     High               Low         High
# 3       aleksatodorovicev     High              High         High
# 4        grigoruadisveley     High              High         High
# ..                    ...      ...               ...          ...
# 95            dal.vivanco      Low              High         High
# 96          musicallygina     High              High         High
# 97            sammy_finch     High              High         High
# 98  hopetaylorphotography     High              High         High
# 99           coach_moyses      Low              High         High
#
#    Agreeableness Neuroticism      Type  media_count  \
# 0           High         Low  Personal          504
# 1           High         Low  Personal         2381
# 2           High         Low  Personal          129
# 3            Low         Low  Personal          897
# 4            Low         Low  Personal        10742
# ..           ...         ...       ...          ...
# 95          High         Low  Personal          199
# 96          High         Low  Personal          349
# 97          High         Low  Personal          586
# 98          High         Low  Business         5744
# 99           Low         Low  Personal          900
#
#                          full_name  following_count  ...  \
# 0                    Patrick Breen              893  ...
# 1                  LINDSEY WHEELER             1332  ...
# 2    Author Kamisha Wells RDKS CEO              314  ...
# 3                Todorović Aleksa              876  ...
# 4      Anzhelika Grigoryadis Veley              980  ...
# ..                             ...              ...  ...
# 95             Hell’s Lady Barber🔥              121  ...
# 96                          Gina 🎶              826  ...
# 97                     Sammy Finch              770  ...
# 98                     Hope Taylor             1436  ...
# 99  M o y s e s  S a n t a n a🇧🇷🇺🇸             1352  ...
#
#                                          external_url engagement_percent  \
# 0                                                 NaN              2.793
# 1                        https://www.lovelindsey.com/              1.063
# 2            https://www.amazon.com/shop/authorkwells              1.804
# 3                 https://linktr.ee/aleksatodorovicev              0.703
# 4                 https://paysend.com/referral/01g6gi              0.470
# ..                                                ...                ...
# 95                                                NaN              2.330
# 96                    https://linktr.ee/musicallygina              0.330
# 97                        http://linktr.ee/getcontact              0.787
# 98            https://linktr.ee/hopetaylorphotography              1.765
# 99  https://www.evogennutrition.com/?aff=1777&_utm...              1.239
#
#                                 email  contact_phone_number  \
# 0       patrick@patrickbreenmusic.com                   NaN
# 1           lindseyslularoe@gmail.com          +17576206307
# 2              kamishawells@yahoo.com          +15627350110
# 3           todorovicaskela@gmail.com                   NaN
# 4    anzhelika-grigorjadis@rambler.ru                   NaN
# ..                                ...                   ...
# 95               daaleery@hotmail.com                   NaN
# 96           ginareneemusic@gmail.com                   NaN
# 97              sammyfinch8@gmail.com                   NaN
# 98  hopetaylorphotography@hotmail.com                   NaN
# 99              moyses_1979@yahoo.com                   NaN
#
#                    cityName         category  \
# 0                       NaN         Musician
# 1                       NaN     Entrepreneur
# 2   Los Angeles, California           Author
# 3                       NaN  Digital creator
# 4                       NaN    Public figure
# ..                      ...              ...
# 95                      NaN     Entrepreneur
# 96                      NaN         Musician
# 97                      NaN        Community
# 98                      NaN     Photographer
# 99                      NaN  Fitness Trainer
#
#                                             biography address_street AvgLikes  \
# 0           📍Los Angeles ✨🎵 Morning Light - OUT NOW 👇            NaN  1346.89
# 1   ☕️ Caffeine, cute clothes & plenty of humor 🤣 ...            NaN   503.44
# 2   📚Available on @amazon | ARF Grouphome| Entrepr...            NaN   887.28
# 3   PR & Digital Marketing Specialist Menswear | T...            NaN   345.72
# 4   🎡🗽✈️🏝📱🛸Official account ✈️#london 🅰️PR manager...            NaN   234.39
# ..                                                ...            ...      ...
# 95  Dálery Vivanco Dueña y Barbera de @hell.razo...            NaN  1132.67
# 96  Singer/Songwriter/Social Media Manager #EndThe...            NaN   152.50
# 97                  Contact to get your account back:            NaN   380.33
# 98  Charleston + Savannah photographer ☀️ Photogra...            NaN   857.28
# 99  👨🏽‍💻 Founder @teamcoachmoysesfit  📖 Published ...            NaN   606.67
#
#    AvgComments
# 0        49.72
# 1        28.11
# 2        14.39
# 3         5.67
# 4         0.72
# ..         ...
# 95       18.83
# 96       10.67
# 97        8.61
# 98       14.72
# 99        5.44
#
# [95 rows x 22 columns]

# %%
bad_users
# Out:
#     comments_count  like_count  \
# 0               10         177
# 1                9         459
# 2                4         334
# 3                2         141
# 4               16         548
# 5               13         741
# 6               35        1791
# 7               24         321
# 8                4          94
# 9               32         603
# 10              22         524
# 11              93         695
# 12               3         187
# 13              20         230
# 14              18         684
# 15              16         265
# 16              15         284
# 17               8         261
# 18              26         262
# 19              99       11972
# 20              60         662
# 21              12         262
# 22               8         230
# 23              61         678
# 24              12         223
# 0                4         378
# 1               26         620
# 2              142         877
# 3               71         569
# 4               14         228
# 5                7         175
# 6                4         269
# 7               15         338
# 8                9         431
# 9               42         537
# 10              10         208
# 11              26         525
# 12              10         282
# 13              36        1025
# 14              22         277
# 15              28         629
# 16              22         148
# 17               4        1274
# 18               9         253
# 19               8         321
# 20              26         502
# 21              31         527
# 22              16         740
# 23               0          29
# 24               4          30
#
#                                               caption  \
# 0   Disfruta experiencias, consigue energías única...
# 1   ¿Porque no buscar la profesionalización?. Si r...
# 2   ¿Es lo mismo vender $1,000 USD en productos qu...
# 3   Mis pensamientos 💭 #24\n\n✅ ¿Cuánto vale mi li...
# 4   Uno de mis grandes errores y de tanto que me l...
# 5   ¿Que está haciendo para cambiar tu realidad? |...
# 6   El cambio de mentalidad 🧠 es necesario y este ...
# 7   Describo los 4 tipos de usuarios de las redes ...
# 8   Mis Pensamientos 💭 #23\n\n✅ ¿Todos podemos ser...
# 9   Salí por las calles de Midtown Miami y me veía...
# 10  ¿Que harías si hoy tienes $1,000,000 usd?. No ...
# 11  ¿Es necesario mostrar LifeStyle, dinero , etc?...
# 12  ¿Y tú qué contenido consumes? Después no te qu...
# 13  Mis pensamientos 💭 #22\n\n✅ contenido viral 💣💣...
# 14  Feliz día a todas las madres.\n\nEl mejor prem...
# 15  ¿Quien hace viral el contenido? Este video no ...
# 16  Mis Pensamientos 💭 #21\n\n✅ #ayahusca vive la ...
# 17  La edad no te impide empezar de 0 y mucho meno...
# 18               Mis pensamientos 💭 #20 \n\n✅ Actitud
# 19  El trabajo no denigra, hazlo con amor y ten ac...
# 20  Yo ✅ siendo Yo y si no puedes ser tú ¿para qué...
# 21  Preocúpate por ti, cuando seas tu prioridad, d...
# 22  ✅ ¿Monetizar Online? \nEn el episodio #18 habl...
# 23  Que no te de miedo empezar| Sígueme en gocholi...
# 24  Trabaja tus capacidades si no las tienes créal...
# 0   ¿Construyendo o sobreviviendo? Despiértate 🚀| ...
# 1   Y tus fines de semana son de construir la vida...
# 2   Prefiero estar en depresión con abundancia, qu...
# 3   Siguen vendiéndonos la pobreza te quieren dorm...
# 4   Paso a paso para hacer Trading y no morir en e...
# 5   Sube volumen solo 1 minuto Cierra los ojos y e...
# 6   Mis pensamientos 💭 #17\n\n✅ ¿Como crear capaci...
# 7   Podría cambiar tu vida de manera exponencial ☀...
# 8   ¿Promueves mentalidad de crecimiento y atraes ...
# 9   ¿Conoces alguna? Es de Energías pero pocos ent...
# 10  Como abrir tu cuenta en MOON4TRADERS BROKERAGE...
# 11  🤭🤭 Mujer, chica, novia, esposa comparte este R...
# 12  Mis pensamientos 💭 #16\n\n✅ Misión de todos lo...
# 13  El entorno ⭕️ ¿como es el tuyo? ¿Es duro ? Si ...
# 14  La vida es un ciclo y debes entender el poder ...
# 15  No necesitas un plan perfecto, pero debes tene...
# 16  La doble moral. Sube el volumen y escucha. ¿po...
# 17  Falsa expectativa en los negocios y en las vid...
# 18  Mis pensamientos 💭 #15\n\nLive que tendrá meno...
# 19  Organización y un plan es todo lo que necesita...
# 20  ¿Sabes tu valor ? Tu puedes hacer más, solo AT...
# 21  Aplícalo vas a ganar más. El autocontrol es in...
# 22  Vuélvete más egoísta. Primero TÚ 💚☀️| Sigueme ...
# 23                                                NaN
# 24  Moon4Traders Brokerage \n\nEres trader ? Estás...
#
#                    timestamp      media_type                 id
# 0   2023-06-03T17:34:43+0000           VIDEO  17984504828287899
# 1   2023-06-02T20:56:37+0000           VIDEO  17997649444762779
# 2   2023-05-31T16:08:33+0000           VIDEO  17843000417997983
# 3   2023-05-30T01:19:57+0000           VIDEO  17917932257738997
# 4   2023-05-29T19:41:38+0000           VIDEO  17948218706509853
# 5   2023-05-27T17:36:22+0000           VIDEO  17956552472415575
# 6   2023-05-25T19:17:43+0000           VIDEO  18015778849607365
# 7   2023-05-23T12:05:04+0000           VIDEO  17857162097932389
# 8   2023-05-23T01:29:57+0000           VIDEO  18091497460336247
# 9   2023-05-22T16:55:44+0000           IMAGE  17911097939764827
# 10  2023-05-21T14:30:25+0000           VIDEO  18016689274603495
# 11  2023-05-19T19:41:31+0000           VIDEO  18055337329414542
# 12  2023-05-16T17:16:33+0000           VIDEO  18363646957057542
# 13  2023-05-16T01:56:35+0000           VIDEO  17994293431915762
# 14  2023-05-14T18:11:26+0000  CAROUSEL_ALBUM  17997332209859157
# 15  2023-05-12T18:42:28+0000           VIDEO  17989543009985994
# 16  2023-05-09T01:58:32+0000           VIDEO  18045379180437455
# 17  2023-05-08T20:04:57+0000           VIDEO  18031615933491446
# 18  2023-05-02T02:44:23+0000           VIDEO  17990087566942021
# 19  2023-05-01T23:17:18+0000           VIDEO  17984744465024595
# 20  2023-04-30T22:53:29+0000  CAROUSEL_ALBUM  18007220923715600
# 21  2023-04-24T12:36:30+0000           VIDEO  17964980774239480
# 22  2023-04-22T20:48:33+0000           VIDEO  17990200231934205
# 23  2023-04-21T12:15:48+0000           VIDEO  18117992494307132
# 24  2023-04-18T22:33:13+0000           VIDEO  17982023927085878
# 0   2023-04-16T23:05:11+0000           VIDEO  17968189598362209
# 1   2023-04-15T15:56:33+0000           VIDEO  17887191131763985
# 2   2023-04-14T16:49:46+0000           VIDEO  18010045570609332
# 3   2023-04-13T16:32:00+0000           VIDEO  17920576403698050
# 4   2023-04-12T15:56:28+0000           VIDEO  17953410029380207
# 5   2023-04-11T11:59:31+0000           VIDEO  17975388842287957
# 6   2023-04-11T02:00:56+0000           VIDEO  17997492337809617
# 7   2023-04-10T12:32:19+0000           VIDEO  17998136599744214
# 8   2023-04-09T15:34:24+0000           VIDEO  17987085991944601
# 9   2023-04-08T19:38:54+0000           VIDEO  18355738027055648
# 10  2023-04-08T02:05:39+0000           VIDEO  17900635979698508
# 11  2023-04-05T12:38:07+0000           VIDEO  18016056925558536
# 12  2023-04-04T01:13:24+0000           VIDEO  17982231149069116
# 13  2023-04-03T19:43:31+0000           VIDEO  17991326098880787
# 14  2023-04-02T16:21:34+0000           VIDEO  17948166956573312
# 15  2023-04-01T14:49:13+0000           VIDEO  17967303065125519
# 16  2023-03-30T20:26:46+0000           VIDEO  17893226645730332
# 17  2023-03-28T19:56:42+0000           VIDEO  18084527752335817
# 18  2023-03-28T01:57:13+0000           VIDEO  17864672459903588
# 19  2023-03-26T22:20:52+0000           VIDEO  17946261005556383
# 20  2023-03-25T15:35:54+0000           VIDEO  18018321289522534
# 21  2023-03-24T17:15:17+0000           VIDEO  18041890729403074
# 22  2023-03-23T16:42:47+0000           VIDEO  18077226592344645
# 23  2023-03-23T16:30:11+0000           VIDEO  17985075412835254
# 24  2023-03-22T16:12:56+0000           VIDEO  18181603345270442

# %%
len(os.listdir("feature/buy_insta_accounts"))
# Out:
# 61

# %%
df_buy_insta_accounts[df_buy_insta_accounts.username == ig_username]
# Out:
#        username Openness Conscientiousness Extroversion Agreeableness  \
# 5452  anyelo_rr     High               Low         High           Low
#
#      Neuroticism      Type  media_count  full_name  following_count  ...  \
# 5452         Low  Personal          898  Anyelo RR              350  ...
#
#                                    external_url engagement_percent  \
# 5452  https://m.youtube.com/watch?v=GqGVkJVk6Ds              2.037
#
#                            email  contact_phone_number cityName category  \
# 5452  anyelorrtheghost@gmail.com                   NaN      NaN   Artist
#
#                                               biography address_street  \
# 5452  👻 GHOST 👻  BOOKING : Anyelorrbooking@gmail.com...            NaN
#
#      AvgLikes AvgComments
# 5452   988.39       39.67
#
# [1 rows x 22 columns]

# %%
# !pip install emot
# Out:
# Requirement already satisfied: emot in /opt/conda/lib/python3.10/site-packages (2.1)

# %%
# Out:
# [PosixPath('feature/buy_insta_accounts'),
#  PosixPath('feature/buy_insta_accounts_add_on'),
#  PosixPath('feature/buy_biz')]

# %%
#combine 
import pandas as pd
from pathlib import Path

p = Path('feature')
folders = [x for x in p.iterdir() if x.is_dir() and x.stem.startswith("buy")]

full_df = pd.DataFrame()
for data_dir in folders:
    for parquet_file in data_dir.glob('*.parquet'):
        ig_username = parquet_file.stem
        df = pd.read_parquet(parquet_file)
        df['ig_username'] = ig_username
        full_df = pd.concat([full_df, df])

# %%
full_df
# Out:
#     comments_count  like_count  \
# 0               22       464.0
# 1                7       130.0
# 2               36       846.0
# 3               13       190.0
# 4               23       460.0
# ..             ...         ...
# 20              23       842.0
# 21              14       627.0
# 22              10       692.0
# 23              20       586.0
# 24              43       742.0
#
#                                               caption  \
# 0                             Baby Rock on tour 🤘🏽🍼🎶🚐
# 1   Este viernes actuaré con mi banda en  Mislata ...
# 2   Resumen de la minigira Aragonesa. \nLo pasamos...
# 3   Esta semana nos vamos de conciertos por tierra...
# 4   ¡Gracias, MADRID! 🥰👏🏼\n Siempre es un gustazo ...
# ..                                                ...
# 20  “The desire to create is one of the deepest ye...
# 21  "It is presentation which lifts the card trick...
# 22  "Creativity makes a leap, then looks to see wh...
# 23                When nothing goes right... Go left!
# 24  “Creativity is seeing what everyone else has s...
#
#                    timestamp      media_type                 id  \
# 0   2023-06-02T12:37:44+0000           IMAGE  17967961775389122
# 1   2023-05-30T12:01:51+0000           IMAGE  17960665451581426
# 2   2023-05-29T15:02:14+0000  CAROUSEL_ALBUM  18362698420034400
# 3   2023-05-22T11:01:23+0000  CAROUSEL_ALBUM  17956348343561063
# 4   2023-05-15T17:18:16+0000  CAROUSEL_ALBUM  17977392881476269
# ..                       ...             ...                ...
# 20  2015-10-24T21:25:32+0000           IMAGE  17845192774030704
# 21  2015-10-21T06:36:54+0000           IMAGE  17845122445030704
# 22  2015-10-20T08:20:54+0000           IMAGE  17844830602030704
# 23  2015-10-18T20:14:23+0000           IMAGE  17844269023030704
# 24  2015-10-17T17:51:59+0000           IMAGE  17844249061030704
#
#        ig_username
# 0   georginamusica
# 1   georginamusica
# 2   georginamusica
# 3   georginamusica
# 4   georginamusica
# ..             ...
# 20  keychainsocial
# 21  keychainsocial
# 22  keychainsocial
# 23  keychainsocial
# 24  keychainsocial
#
# [13317 rows x 7 columns]

# %% [markdown]
# ## Preprocess Features

# %%
from emot.emo_unicode import UNICODE_EMO, EMOTICONS
import re

def lower_text(text):
    try:
        text = text.lower()
    except:
        return ""
    return text
def remove_newline(string):
    string = string.replace("\n", "")
    return string
def remove_punctuation(string): 
    punctuations = '''()-[]{};:'"\<>/@#$%^&*~'''
    for x in string.lower(): 
        if x in punctuations: 
            string = string.replace(x, "")
        elif x == ",._":
            string = string.replace(x, " ")
        elif x == "?":
            string = string.replace(x, "[question mark]")
    return string

def convert_emojis(text):
    for emot in UNICODE_EMO:
        text = text.replace(emot, "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()))
    return text

def convert_emoticons(text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    return text

def combine_metadata(row):
    return f"caption {row['caption']}, is of type {row['media_type'].lower()}, has {row['comments_count']} comments and {row['like_count']} likes"

# %%
full_df['full_caption'] = full_df.apply(combine_metadata, axis=1)
full_df['full_caption'] = full_df['full_caption'].apply(lower_text)
full_df['full_caption'] = full_df['full_caption'].apply(remove_newline)
full_df['full_caption'] = full_df['full_caption'].apply(convert_emojis)
full_df['full_caption'] = full_df['full_caption'].apply(convert_emoticons)
full_df_concat = full_df[['ig_username','full_caption']].groupby("ig_username").sum()

# %%
full_df_concat
# Out:
#                                                        full_caption
# ig_username
# 36mktg            caption did you know henry ford made the 8 hou...
# 6staroileaters    caption so clean smiling_face_with_heart-eyesr...
# 740project        caption through the night crescent_moon • maet...
# _boostfruit.com_  caption take your social media accounts out of...
# _cloutfinder      caption appreciate you excellencealways folded...
# ...                                                             ...
# wipmarketing      caption none, is of type image, has 1 comments...
# xcarmeeen         caption enjoy this video while i disappear for...
# xflvipers         caption power back.#fanggang | xfl, is of type...
# yogabody_uk       caption summeeeeer! all the hard work of clean...
# zgroupla          caption now booking grammy award winning artis...
#
# [268 rows x 1 columns]

# %%
columns = ['username', 'Openness','Conscientiousness','Extroversion','Agreeableness','Neuroticism']
feature_df =full_df_concat.merge(gc_df, left_index=True, right_on="username", how="left")
gc_df = pd.concat([
    df_buy_insta_accounts[columns],
    df_buy_biz[columns],
    df_buy_insta_accounts_add_on[columns]
])

# %%
feature_df
# Out:
#                                            full_caption          username  \
# 59    caption did you know henry ford made the 8 hou...            36mktg
# 69    caption so clean smiling_face_with_heart-eyesr...    6staroileaters
# 26    caption through the night crescent_moon • maet...        740project
# 57    caption take your social media accounts out of...  _boostfruit.com_
# 10    caption appreciate you excellencealways folded...      _cloutfinder
# ...                                                 ...               ...
# 71    caption none, is of type image, has 1 comments...      wipmarketing
# 14    caption enjoy this video while i disappear for...         xcarmeeen
# 5461  caption power back.#fanggang | xfl, is of type...         xflvipers
# 67    caption summeeeeer! all the hard work of clean...       yogabody_uk
# 84    caption now booking grammy award winning artis...          zgroupla
#
#       Openness  Conscientiousness  Extroversion  Agreeableness  Neuroticism
# 59         1.0                1.0           1.0            1.0          0.0
# 69         0.0                1.0           0.5            0.5          0.5
# 26         1.0                0.0           0.0            0.0          0.5
# 57         1.0                0.0           1.0            0.5          0.5
# 10         1.0                0.0           1.0            0.5          0.5
# ...        ...                ...           ...            ...          ...
# 71         1.0                1.0           1.0            1.0          0.0
# 14         0.0                0.0           1.0            0.0          1.0
# 5461       0.0                1.0           1.0            1.0          0.0
# 67         1.0                1.0           1.0            1.0          0.0
# 84         1.0                0.0           1.0            0.5          0.5
#
# [269 rows x 7 columns]

# %%
feature_df['Openness'] = feature_df['Openness'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Conscientiousness'] = feature_df['Conscientiousness'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Extroversion'] = feature_df['Extroversion'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Agreeableness'] = feature_df['Agreeableness'].map({"High":1.0,"Low":0,"Vague":0.5})
feature_df['Neuroticism'] = feature_df['Neuroticism'].map({"High":1.0,"Low":0,"Vague":0.5})

# %%
feature_so_far = feature_so_far.dropna()

# %%
feature_df.to_parquet("feature.parquet")
